# %%
import os
print(os.getcwd())
os.chdir('d:\\vscode_machineLearning\\internship\\Customer-Churn-Prediction')
print(os.getcwd())
# Out:
# d:\vscode_machineLearning\internship\Customer-Churn-Prediction\experiments\EDA
# d:\vscode_machineLearning\internship\Customer-Churn-Prediction

# %%
import pandas as pd
from ensure import ensure_annotations
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv(r'artifacts/raw_data/customer_churn_removed_col.csv')

# %% [markdown]
# ### all numerical columns distribution

# %%
cat_cols =[feature for feature in df.columns if df[feature].dtype == 'O']
num_cols =[feature for feature in df.columns if df[feature].dtype != 'O']
print(cat_cols)
print(num_cols)
# Out:
# ['Gender', 'Location']
# ['Age', 'Subscription_Length_Months', 'Monthly_Bill', 'Total_Usage_GB', 'Churn']

# %%
plt.subplots(nrows=2,ncols=2,figsize = (25,12))
plt.subplot(2,2,1)
ax = sns.histplot(data=df[num_cols]['Age'],kde=True,color='g')
# for i in ax.containers:
#     ax.bar_label(i)
plt.title('Age Distribution')
plt.subplot(2,2,2)
ax = sns.histplot(data=df[num_cols]['Subscription_Length_Months'],kde=True,color='y')
# for i in ax.containers:
#     ax.bar_label(i)
plt.subplot(2,2,3)
sns.histplot(data=df[num_cols]['Monthly_Bill'],kde=True)
plt.subplot(2,2,4)
ax = sns.histplot(data=df[num_cols]['Total_Usage_GB'],kde=True,color='b')
# for i in ax.containers:
#     ax.bar_label(i)

# %% [markdown]
# ### Comparing all with `Churn`

# %%
num_cols
# Out:
# ['Age',
#  'Subscription_Length_Months',
#  'Monthly_Bill',
#  'Total_Usage_GB',
#  'Churn']

# %%
cat_cols
# Out:
# ['Gender', 'Location']

# %%
plt.subplots(nrows=1,ncols=2,figsize = (20,7))

plt.subplot(1,3,1)
ax = sns.histplot(data=df,x=df['Age'],color='g',hue='Gender',)
plt.title('Gender')
plt.xticks(rotation = 'vertical')

plt.subplot(1,3,2)
ax = sns.histplot(data=df,x=df['Age'],color='y',hue='Location')
plt.xticks(rotation = 'vertical')
plt.title(label='Location')

plt.subplot(1,3,3)
sns.histplot(data=df,x=df['Age'],hue=df['Churn'])
plt.title('Churn',)
plt.xticks(rotation = 'vertical')

print(f'{df["Gender"].value_counts().head(1)}') 
print('')
print(f'{df["Location"].value_counts().head(1)}') 
print('')
print(f'{df["Churn"].value_counts().head(1)}') 
print('')
# Out:
# Gender
# Female    50216
# Name: count, dtype: int64
#
# Location
# Houston    20157
# Name: count, dtype: int64
#
# Churn
# 0    50221
# Name: count, dtype: int64

# %%
plt.subplots(nrows=1,ncols=2,figsize = (20,7))

plt.subplot(1,3,1)
ax = sns.histplot(data=df,x=df['Age'],color='g',hue='Gender',kde=True)
plt.title('Gender')
plt.xticks(rotation = 'vertical')

plt.subplot(1,3,2)
ax = sns.histplot(data=df,x=df['Age'],kde=True,color='y',hue='Location')
plt.xticks(rotation = 'vertical')
plt.title(label='Location')

plt.subplot(1,3,3)
sns.histplot(data=df,x=df['Age'],kde=True,hue=df['Churn'])
plt.title('Churn',)
plt.xticks(rotation = 'vertical')
# Out:
# (array([10., 20., 30., 40., 50., 60., 70., 80.]),
#  [Text(10.0, 0, '10'),
#   Text(20.0, 0, '20'),
#   Text(30.0, 0, '30'),
#   Text(40.0, 0, '40'),
#   Text(50.0, 0, '50'),
#   Text(60.0, 0, '60'),
#   Text(70.0, 0, '70'),
#   Text(80.0, 0, '80')])

# %% [markdown]
# ## Insights
# with respect to age the data is equally distributed.

# %%
num_cols
# Out:
# ['Age',
#  'Subscription_Length_Months',
#  'Monthly_Bill',
#  'Total_Usage_GB',
#  'Churn']

# %%
plt.subplots(nrows=1,ncols=2,figsize = (20,7))

plt.subplot(1,3,1)
ax = sns.histplot(data=df,x=df['Subscription_Length_Months'],color='g',hue='Gender',kde=True)
plt.title('Gender')
plt.xticks(rotation = 'vertical')

plt.subplot(1,3,2)
ax = sns.histplot(data=df,x=df['Subscription_Length_Months'],kde=True,color='y',hue='Location')
plt.xticks(rotation = 'vertical')
plt.title(label='Location')

plt.subplot(1,3,3)
sns.histplot(data=df,x=df['Subscription_Length_Months'],kde=True,hue=df['Churn'])
plt.title('Churn',)
plt.xticks(rotation = 'vertical')
# Out:
# (array([-5.,  0.,  5., 10., 15., 20., 25., 30.]),
#  [Text(-5.0, 0, '−5'),
#   Text(0.0, 0, '0'),
#   Text(5.0, 0, '5'),
#   Text(10.0, 0, '10'),
#   Text(15.0, 0, '15'),
#   Text(20.0, 0, '20'),
#   Text(25.0, 0, '25'),
#   Text(30.0, 0, '30')])

# %% [markdown]
# ## Insights
# with respect to Subscription_Length_Months also the data is equally distributed.

# %%
plt.subplots(nrows=1,ncols=2,figsize = (20,7))

plt.subplot(1,3,1)
ax = sns.histplot(data=df,x=df['Monthly_Bill'],color='g',hue='Gender',kde=True)
plt.title('Gender')
plt.xticks(rotation = 'vertical')

plt.subplot(1,3,2)
ax = sns.histplot(data=df,x=df['Monthly_Bill'],kde=True,color='y',hue='Location')
plt.xticks(rotation = 'vertical')
plt.title(label='Location')

plt.subplot(1,3,3)
sns.histplot(data=df,x=df['Monthly_Bill'],kde=True,hue=df['Churn'])
plt.title('Churn',)
plt.xticks(rotation = 'vertical')
# Out:
# (array([ 20.,  30.,  40.,  50.,  60.,  70.,  80.,  90., 100., 110.]),
#  [Text(20.0, 0, '20'),
#   Text(30.0, 0, '30'),
#   Text(40.0, 0, '40'),
#   Text(50.0, 0, '50'),
#   Text(60.0, 0, '60'),
#   Text(70.0, 0, '70'),
#   Text(80.0, 0, '80'),
#   Text(90.0, 0, '90'),
#   Text(100.0, 0, '100'),
#   Text(110.0, 0, '110')])

# %% [markdown]
# ## Insights
# There's not any much difference with respect to `Monthly_Bill` also.

# %%
plt.subplots(nrows=1,ncols=2,figsize = (20,7))

plt.subplot(1,3,1)
ax = sns.histplot(data=df,x=df['Total_Usage_GB'],color='g',hue='Gender',kde=True)
plt.title('Gender')
plt.xticks(rotation = 'vertical')

plt.subplot(1,3,2)
ax = sns.histplot(data=df,x=df['Total_Usage_GB'],kde=True,color='y',hue='Location')
plt.xticks(rotation = 'vertical')
plt.title(label='Location')

plt.subplot(1,3,3)
sns.histplot(data=df,x=df['Total_Usage_GB'],kde=True,hue=df['Churn'])
plt.title('Churn',)
plt.xticks(rotation = 'vertical')
# Out:
# (array([  0., 100., 200., 300., 400., 500., 600.]),
#  [Text(0.0, 0, '0'),
#   Text(100.0, 0, '100'),
#   Text(200.0, 0, '200'),
#   Text(300.0, 0, '300'),
#   Text(400.0, 0, '400'),
#   Text(500.0, 0, '500'),
#   Text(600.0, 0, '600')])

# %% [markdown]
# ## Same Here.

# %%
plt.subplots(nrows=1,ncols=2,figsize = (20,7))

plt.subplot(1,3,1)
ax = sns.histplot(data=df,x=df['Churn'],color='g',hue='Gender',kde=True)
for i in ax.containers:
    ax.bar_label(i)
plt.title('Gender')
plt.xticks(rotation = 'vertical')

plt.subplot(1,3,2)
ax = sns.histplot(data=df,x=df['Churn'],kde=True,color='y',hue='Location')
for i in ax.containers:
    ax.bar_label(i)
plt.xticks(rotation = 'vertical')
plt.title(label='Location')

plt.subplot(1,3,3)
ax = sns.histplot(data=df,x=df['Churn'],kde=True,hue=df['Churn'])
for i in ax.containers:
    ax.bar_label(i)
plt.title('Churn',)
plt.xticks(rotation = 'vertical')
# Out:
# (array([-0.2,  0. ,  0.2,  0.4,  0.6,  0.8,  1. ,  1.2]),
#  [Text(-0.2, 0, '−0.2'),
#   Text(0.0, 0, '0.0'),
#   Text(0.2, 0, '0.2'),
#   Text(0.4000000000000001, 0, '0.4'),
#   Text(0.6000000000000001, 0, '0.6'),
#   Text(0.8, 0, '0.8'),
#   Text(1.0000000000000002, 0, '1.0'),
#   Text(1.2000000000000002, 0, '1.2')])

# %% [markdown]
# ## theres not that much difference

# %% [markdown]
# ## Insight
# Almost equal distribution of all classes

# %% [markdown]
# ## Multivariate analysis using pieplot

# %%
df['Location'].value_counts().index.tolist()
# Out:
# ['Houston', 'Los Angeles', 'Miami', 'Chicago', 'New York']

# %%
plt.rcParams['figure.figsize'] = (30, 12)

plt.subplot(1, 5, 1)
size = df['Gender'].value_counts()
labels = 'Female', 'Male'
color = ['red','green']


plt.pie(size, colors = color, labels = labels,autopct = '.%2f%%')
plt.title('Gender', fontsize = 20)
plt.axis('off')



plt.subplot(1, 5, 2)
size = df['Location'].value_counts()
labels = 'Houston', 'Los Angeles', 'Miami', 'Chicago', 'New York'
color = ['red', 'green', 'blue', 'cyan','orange','pink']

plt.pie(size, colors = color,labels = labels,autopct = '.%2f%%')
plt.title('Location', fontsize = 20)
plt.axis('off')

plt.subplot(1, 5, 3)
size = df['Churn'].value_counts()
labels = 'Standard', 'Free'
color = ['red','green']

plt.pie(size, colors = color,labels = labels,autopct = '.%2f%%')
plt.title('Churn', fontsize = 20)
plt.axis('off')


plt.tight_layout()
plt.grid()

plt.show()

# %% [markdown]
# ## Almost equally distribution of each class in each feature.

# %% [markdown]
# # Correlation

# %%
plt.figure(figsize=(15,6))
sns.heatmap(data=df[num_cols].corr(),annot=True)
# Out:
# <Axes: >

# %% [markdown]
# ## not correlated

# %% [markdown]
# ## Num columns correlation

# %%
num_cols
# Out:
# ['Age',
#  'Subscription_Length_Months',
#  'Monthly_Bill',
#  'Total_Usage_GB',
#  'Churn']

# %%
plt.subplots(nrows=2, ncols=2, figsize=(20, 12))

plt.subplot(2, 2, 1)
ax = sns.scatterplot(data=df[num_cols], x='Age', y='Subscription_Length_Months', hue=df['Churn'], palette='Set1')
plt.title('Age vs Subscription_Length_Months')


plt.subplot(2, 2, 3)
ax = sns.scatterplot(data=df[num_cols], x='Age', y='Monthly_Bill', hue=df['Churn'], palette='Set1')
plt.title('Age vs Monthly_Bill')

plt.subplot(2, 2, 4)
ax = sns.scatterplot(data=df[num_cols], x='Age', y='Total_Usage_GB', hue=df['Churn'], palette='Set1')
plt.title('Age vs Total_Usage_GB')

plt.tight_layout()
plt.show()

# %%
plt.subplots(nrows=2, ncols=2, figsize=(20, 12))

plt.subplot(2, 2, 1)
ax = sns.scatterplot(data=df[num_cols], x='Age', y='Subscription_Length_Months', hue=df['Gender'], palette='Set1')
plt.title('Age vs Inches')

plt.subplot(2, 2, 2)
ax = sns.scatterplot(data=df[num_cols], x='Age', y='Monthly_Bill', hue=df['Gender'], palette='Set1')
plt.title('Age vs Ram')

plt.subplot(2, 2, 3)
ax = sns.scatterplot(data=df[num_cols], x='Age', y='Total_Usage_GB', hue=df['Gender'], palette='Set1')
plt.title('Age vs Weight')

plt.tight_layout()
plt.show()

# %%
f,ax=plt.subplots(1,2,figsize=(20,10))
sns.countplot(x=df['Location'],data=df,palette = 'bright',ax=ax[0],saturation=0.95)
for container in ax[0].containers:
    ax[0].bar_label(container,color='black',size=20)
    
plt.pie(x = df['Location'].value_counts(),labels=df['Location'].value_counts().index,explode=[0.1,0,0,0,0],autopct='%1.1f%%'
        # ,shadow=True
        )
plt.show()

# %%
f,ax=plt.subplots(1,2,figsize=(20,10))
sns.countplot(x=df['Churn'],data=df,palette = 'bright',ax=ax[0],saturation=0.95)
for container in ax[0].containers:
    ax[0].bar_label(container,color='black',size=20)
    
plt.pie(x = df['Churn'].value_counts(),labels=df['Churn'].value_counts().index,explode=[0.1,0],autopct='%1.1f%%'
        # ,shadow=True
        )
plt.show()

# %%
num_cols
# Out:
# ['Age',
#  'Subscription_Length_Months',
#  'Monthly_Bill',
#  'Total_Usage_GB',
#  'Churn']

# %%
plt.figure(figsize=(20,6))
plt.style.use('fivethirtyeight')
plt.subplot(1,4,1)
sns.barplot (x=df['Churn'], y=df['Age'], hue=df['Gender'])
plt.subplot(1,4,2)
sns.barplot (x=df['Churn'], y=df['Subscription_Length_Months'], hue=df['Gender'])
plt.subplot(1,4,3)
sns.barplot (x=df['Churn'], y=df['Monthly_Bill'], hue=df['Gender'])
plt.subplot(1,4,4)
sns.barplot (x=df['Churn'], y=df['Total_Usage_GB'], hue=df['Gender'])
# Out:
# <Axes: xlabel='Churn', ylabel='Total_Usage_GB'>

# %% [markdown]
# The project was very exciting as well as challenging. I have gain great experience from this project. I had to work 18-20 hour's in 48 hour's.
#
# EDA:
# The dataset you provided was completely symmetric. When I saw the distribute of numeric features that were completely were equally distributed. Then I tried to look into categorical features that were also contributing almost equally distribution to each class in each feature.
#
# Data Transformation:
# I was to check the model's performance with data transformation so I first I normalized the data(for best practices) but the models accuracy came 50%. So I changed the model but I was getting the same accuracy than, I thought that I should use different technique so I transformed the data into Gaussian Distribution(using np.log()) but the accuracy remain same. Than I thought not transforming the data must be good choice but still the accuracy remain same.
#
# Data Generation:
# In order to get better accuracy I even tried to generate data using SOMTE but still I was getting the same accuracy.
#
# Model Training:
# I thought if I will use xgboot or Gradientboost then I should get better result's but, unfortunately I was still stuck in the 50% accuracy.
# Than I done hyperparameter tuning using (RandomsearchCV) but still my model's accuracy remain same.
# Than I thought neural networks may perform well So I trained the neural network with best practices and also used different different weight Initializers , activation functions ,input nodes and optimizer, But nothing accuracy remain same.
#
# Model Evaluation:
# I have used MLFlow for model evaluation with Dagshub to handle all these things remotly which helped to track the models parameter, model performance metrics and I was able to select the best model by comparing.
# Deployment:
# I have deployed the model in Streamlit. I will deploy the model in AWS but because of the time limit I am unable to deploy yet.
#
# Best Practices I have included:
# - Modular programming (For clean code)
# - Neural network and Machine learning algorithms
# - MLflow and Dagshug(for model evaluation)
# - Streamlit (for model deployment)
# - SMOTE(for data generation)
#
# Thank you considering myself for this internship.If I get selected I am looking forward for interveiw round .
